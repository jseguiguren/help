# %% [markdown]
# <a href="https://colab.research.google.com/github/jseguiguren/help/blob/main/chromosome_end_genes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Define the Ensembl REST API endpoint and species
ensembl_endpoint = "https://rest.ensembl.org"
species = "danio_rerio"  # Zebrafish species

# Fetch chromosome information from Ensembl
chromosomes_url = f"{ensembl_endpoint}/info/assembly/{species}"
chromosomes_response = requests.get(chromosomes_url, headers={"Content-Type": "application/json"})

if chromosomes_response.status_code == 200:
    chromosomes_data = chromosomes_response.json()
    chromosomes = chromosomes_data['top_level_region']
else:
    print(f"Error fetching chromosome information: {chromosomes_response.status_code}")
    chromosomes = []

# Define telomeric regions (both sides of each chromosome)
telomeric_regions = []

for chromosome in chromosomes:
    if chromosome['name'].startswith("chrUn"):  # Skip 'chrUn' chromosomes
        continue

    telomeric_regions.append(
        {"chr": chromosome['name'], "start": 1, "end": 100000}
    )
    telomeric_regions.append(
        {"chr": chromosome['name'], "start": chromosome['length'] - 100000, "end": chromosome['length']}
    )

# Define the distance threshold to consider genes as "close" to telomeres
proximity_threshold = 10000  # Example threshold distance

# Fetch gene information from Ensembl for each telomeric region
genes_near_telomeres = []

for region in telomeric_regions:
    region_str = f"{region['chr']}:{region['start']}-{region['end']}"
    url = f"{ensembl_endpoint}/overlap/region/{species}/{region_str}?feature=gene"

    response = requests.get(url, headers={"Content-Type": "application/json"})

    if response.status_code == 200:
        gene_data = response.json()
        for gene in gene_data:
            if gene['biotype'] == 'protein_coding' and 'external_name' in gene:
                gene_id = gene['id']
                external_gene_name = gene['external_name']
                chromosome_number = region['chr']
                gene_start = gene['start']
                gene_end = gene['end']
                distance_to_telomere = min(
                    abs(gene_start - region['start']),
                    abs(gene_end - region['start']),
                    abs(gene_start - region['end']),
                    abs(gene_end - region['end'])
                )
                if distance_to_telomere <= proximity_threshold:
                    gene_location = "Start" if abs(gene_start - region['start']) < abs(gene_end - region['end']) else "End"
                    genes_near_telomeres.append((chromosome_number, gene_id, external_gene_name, gene_location))
    else:
        print(f"Error fetching data for region {region_str}: {response.status_code}")

# Print the list of protein-coding genes near telomeric regions with external gene names and location
print("Protein-coding genes near telomeric regions with external gene names and location:")
for chromosome, gene_id, external_gene_name, gene_location in genes_near_telomeres:
    print(f"Chromosome {chromosome}: Gene ID {gene_id}, External Gene Name {external_gene_name}, Location {gene_location}")
# Out:
# Error fetching data for region KN149680.1:-61276-38724: 400
# Error fetching data for region KZ116065.1:-62646-37354: 400
# Error fetching data for region KN149692.1:-63089-36911: 400
# Error fetching data for region KN149693.1:-50705-49295: 400
# Error fetching data for region KN150210.1:-87450-12550: 400
# Error fetching data for region KN150211.1:-83614-16386: 400
# Error fetching data for region KN150647.1:-85062-14938: 400
# Error fetching data for region KN150173.1:-49054-50946: 400
# Error fetching data for region KZ116049.1:-91502-8498: 400
# Error fetching data for region KN150174.1:-86550-13450: 400
# Error fetching data for region KN149825.1:-77872-22128: 400
# Error fetching data for region KN149936.1:-83942-16058: 400
# Error fetching data for region KN149933.1:-86567-13433: 400
# Error fetching data for region KZ116059.1:-65967-34033: 400
# Error fetching data for region KN150548.1:-53939-46061: 400
# Error fetching data for region KN149836.1:-65046-34954: 400
# Error fetching data for region KN149732.1:-83959-16041: 400
# Error fetching data for region KN150263.1:-68664-31336: 400
# Error fetching data for region KN150509.1:-88154-11846: 400
# Error fetching data for region KN150510.1:-86763-13237: 400
# Error fetching data for region KN150511.1:-61817-38183: 400
# Error fetching data for region KZ116011.1:-48385-51615: 400
# Error fetching data for region KN150332.1:-77138-22862: 400
# Error fetching data for region KN150161.1:-87353-12647: 400
# Error fetching data for region KN150162.1:-89070-10930: 400
# Error fetching data for region KN150083.1:-50486-49514: 400
# Error fetching data for region KN150084.1:-75808-24192: 400
# Error fetching data for region KN149728.1:-90558-9442: 400
# Error fetching data for region KN150655.1:-91911-8089: 400
# Error fetching data for region KN150656.2:-70678-29322: 400
# Error fetching data for region KN150580.1:-67651-32349: 400
# Error fetching data for region KN150581.1:-87645-12355: 400
# Error fetching data for region KN149747.1:-83725-16275: 400
# Error fetching data for region KZ116050.1:-93347-6653: 400
# Error fetching data for region KN149983.1:-82116-17884: 400
# Error fetching data for region KZ115972.1:-81807-18193: 400
# Error fetching data for region KN150601.1:-88833-11167: 400
# Error fetching data for region KN150274.1:-87753-12247: 400
# Error fetching data for region KN150275.1:-86200-13800: 400
# Error fetching data for region KN150276.1:-87058-12942: 400
# Error fetching data for region KN149863.1:-88045-11955: 400
# Error fetching data for region KN149864.1:-87071-12929: 400
# Error fetching data for region KZ116024.1:-68233-31767: 400
# Error fetching data for region KN150352.2:-74648-25352: 400
# Error fetching data for region KN150250.1:-86440-13560: 400
# Error fetching data for region KZ115995.1:-94886-5114: 400
# Error fetching data for region KZ115976.1:-96619-3381: 400
# Error fetching data for region KN150395.1:-90208-9792: 400
# Error fetching data for region KN150444.1:-88170-11830: 400
# Error fetching data for region KN150445.1:-87928-12072: 400
# Error fetching data for region KN150607.1:-90469-9531: 400
# Error fetching data for region KN150043.1:-68016-31984: 400
# Error fetching data for region KZ116054.1:-85344-14656: 400
# Error fetching data for region KN150343.1:-73072-26928: 400
# Error fetching data for region KN150344.1:-80319-19681: 400
# Error fetching data for region KN150190.1:-88601-11399: 400
# Error fetching data for region KN150350.1:-90755-9245: 400
# Error fetching data for region KN150272.1:-65705-34295: 400
# Error fetching data for region KN149749.1:-59911-40089: 400
# Error fetching data for region KZ116004.1:-80950-19050: 400
# Error fetching data for region KN149837.1:-91993-8007: 400
# Error fetching data for region KN150643.1:-71912-28088: 400
# Error fetching data for region KZ116042.1:-86874-13126: 400
# Error fetching data for region KZ116044.1:-62779-37221: 400
# Error fetching data for region KN149848.1:-89659-10341: 400
# Error fetching data for region KN149849.1:-79579-20421: 400
# Error fetching data for region KN150669.1:-84675-15325: 400
# Error fetching data for region KN150479.1:-51814-48186: 400
# Error fetching data for region KN150490.1:-76943-23057: 400
# Error fetching data for region KN150502.1:-86973-13027: 400
# Error fetching data for region KN150414.1:-64129-35871: 400
# Error fetching data for region KN149794.1:-74560-25440: 400
# Error fetching data for region KN150054.1:-83857-16143: 400
# Error fetching data for region KN150271.1:-87363-12637: 400
# Error fetching data for region KZ115964.1:-78015-21985: 400
# Error fetching data for region KN150446.1:-87554-12446: 400
# Error fetching data for region KN150092.1:-85456-14544: 400
# Error fetching data for region KZ116031.1:-80293-19707: 400
# Error fetching data for region KN149709.1:-72186-27814: 400
# Error fetching data for region KN150020.1:-88075-11925: 400
# Error fetching data for region KN150197.1:-85468-14532: 400
# Error fetching data for region KN149730.1:-85196-14804: 400
# Error fetching data for region KN150213.1:-83899-16101: 400
# Error fetching data for region KN150005.1:-65591-34409: 400
# Error fetching data for region KN150006.1:-89482-10518: 400
# Error fetching data for region KN150007.1:-86928-13072: 400
# Error fetching data for region KZ115952.1:-93255-6745: 400
# Error fetching data for region KZ115955.1:-97351-2649: 400
# Error fetching data for region KN149977.2:-88977-11023: 400
# Error fetching data for region KN150327.1:-80051-19949: 400
# Error fetching data for region KN150665.1:-88056-11944: 400
# Error fetching data for region KN150666.1:-36516-63484: 400
# Error fetching data for region KN150667.1:-45799-54201: 400
# Error fetching data for region KN150251.1:-73012-26988: 400
# Error fetching data for region KN149901.1:-89488-10512: 400
# Error fetching data for region KN149884.1:-48285-51715: 400
# Error fetching data for region KN150619.1:-58075-41925: 400
# Error fetching data for region KN150620.1:-69271-30729: 400
# Error fetching data for region KN149846.1:-71336-28664: 400
# Error fetching data for region KN150081.1:-87164-12836: 400
# Error fetching data for region KN150082.1:-91212-8788: 400
# Error fetching data for region KN150157.1:-81244-18756: 400
# Error fetching data for region KN149915.1:-89605-10395: 400
# Error fetching data for region KN150080.1:-62338-37662: 400
# Error fetching data for region KZ116015.1:-90002-9998: 400
# Error fetching data for region KN150393.1:-87927-12073: 400
# Error fetching data for region KN149887.1:-88029-11971: 400
# Error fetching data for region KN150073.1:-85948-14052: 400
# Error fetching data for region KN150093.1:-85262-14738: 400
# Error fetching data for region KN150094.1:-92176-7824: 400
# Error fetching data for region KZ116014.1:-98464-1536: 400
# Error fetching data for region KN150567.1:-50434-49566: 400
# Error fetching data for region KN149900.1:-88984-11016: 400
# Error fetching data for region KN149995.1:-87985-12015: 400
# Error fetching data for region KN150269.1:-51938-48062: 400
# Error fetching data for region KN150571.1:-83495-16505: 400
# Error fetching data for region KN150134.1:-70933-29067: 400
# Error fetching data for region KN150146.1:-90286-9714: 400
# Error fetching data for region KN149851.1:-87906-12094: 400
# Error fetching data for region KN149852.1:-69777-30223: 400
# Error fetching data for region KN150244.1:-57140-42860: 400
# Error fetching data for region KN150238.1:-90550-9450: 400
# Error fetching data for region KN149989.1:-65520-34480: 400
# Error fetching data for region KN149990.1:-42349-57651: 400
# Error fetching data for region KN149992.1:-42088-57912: 400
# Error fetching data for region KZ116056.1:-89419-10581: 400
# Error fetching data for region KN150436.1:-82261-17739: 400
# Error fetching data for region KZ116055.1:-92771-7229: 400
# Error fetching data for region KN149784.1:-26171-73829: 400
# Error fetching data for region KN149980.1:-92020-7980: 400
# Error fetching data for region KN149991.1:-90129-9871: 400
# Error fetching data for region KN150241.1:-39179-60821: 400
# Error fetching data for region KN150388.1:-77716-22284: 400
# Error fetching data for region KN150400.1:-65070-34930: 400
# Error fetching data for region KN149928.1:-85703-14297: 400
# Error fetching data for region KN150257.1:-87265-12735: 400
# Error fetching data for region KN150268.1:-84720-15280: 400
# Error fetching data for region KN150065.1:-90141-9859: 400
# Error fetching data for region KZ116002.1:-90478-9522: 400
# Error fetching data for region KN149865.1:-50833-49167: 400
# Error fetching data for region KN149866.1:-85248-14752: 400
# Error fetching data for region KN149969.1:-86286-13714: 400
# Error fetching data for region KZ115949.1:-80513-19487: 400
# Error fetching data for region KN150439.1:-89657-10343: 400
# Error fetching data for region KN150519.1:-88026-11974: 400
# Error fetching data for region KN150066.1:-70463-29537: 400
# Error fetching data for region KN150351.1:-50392-49608: 400
# Error fetching data for region KN150183.1:-77734-22266: 400
# Error fetching data for region KN150449.1:-37393-62607: 400
# Error fetching data for region KN150450.1:-74638-25362: 400
# Error fetching data for region KN150303.1:-60712-39288: 400
# Error fetching data for region KZ115971.1:-89001-10999: 400
# Error fetching data for region KN150283.1:-86067-13933: 400
# Error fetching data for region KN150047.1:-79251-20749: 400
# Error fetching data for region KN150651.1:-71982-28018: 400
# Error fetching data for region KN150396.1:-91824-8176: 400
# Error fetching data for region KN150397.1:-82705-17295: 400
# Error fetching data for region KZ115996.1:-94977-5023: 400
# Error fetching data for region KN150700.2:-28285-71715: 400
# Error fetching data for region KN150364.1:-84916-15084: 400
# Error fetching data for region KN150258.1:-4115-95885: 400
# Error fetching data for region KN150259.1:-49902-50098: 400
# Error fetching data for region KN150484.1:-85035-14965: 400
# Error fetching data for region KN150610.1:-89435-10565: 400
# Error fetching data for region KN149748.1:-3430-96570: 400
# Error fetching data for region KN149817.1:-88884-11116: 400
# Error fetching data for region KN150114.1:-75822-24178: 400
# Error fetching data for region KN150549.1:-82401-17599: 400
# Error fetching data for region KN150713.1:-85421-14579: 400
# Error fetching data for region KN149768.1:-82329-17671: 400
# Error fetching data for region KN150196.1:-10923-89077: 400
# Error fetching data for region KZ116028.1:-96711-3289: 400
# Error fetching data for region KN150401.1:-89919-10081: 400
# Error fetching data for region KN149703.1:-86098-13902: 400
# Error fetching data for region KZ116027.1:-95926-4074: 400
# Error fetching data for region KZ116041.1:-87003-12997: 400
# Error fetching data for region KN149764.1:-80169-19831: 400
# Error fetching data for region KZ115970.1:-95036-4964: 400
# Error fetching data for region KN150690.1:-73855-26145: 400
# Error fetching data for region KN150280.1:-89513-10487: 400
# Error fetching data for region KN150291.1:-74204-25796: 400
# Error fetching data for region KN150302.1:-86462-13538: 400
# Error fetching data for region KN150011.1:-87005-12995: 400
# Error fetching data for region KN150177.1:-78330-21670: 400
# Error fetching data for region KN150227.1:-68021-31979: 400
# Error fetching data for region KN150071.1:-85040-14960: 400
# Error fetching data for region KN150072.1:-86691-13309: 400
# Error fetching data for region KZ115999.1:-91058-8942: 400
# Error fetching data for region KN150443.1:-88166-11834: 400
# Error fetching data for region KN150165.1:-67261-32739: 400
# Error fetching data for region KN150121.1:-91553-8447: 400
# Error fetching data for region KN150097.1:-88310-11690: 400
# Error fetching data for region KN150379.1:-70093-29907: 400
# Error fetching data for region KN150556.1:-90714-9286: 400
# Error fetching data for region KN150420.1:-85710-14290: 400
# Error fetching data for region KN149839.1:-87002-12998: 400
# Error fetching data for region KN150200.1:-68139-31861: 400
# Error fetching data for region KN150299.1:-76489-23511: 400
# Error fetching data for region KN149922.1:-87471-12529: 400
# Error fetching data for region KZ115991.1:-96255-3745: 400
# Error fetching data for region KN149793.1:-86702-13298: 400
# Error fetching data for region KN150045.2:-89636-10364: 400
# Error fetching data for region KN149807.1:-87488-12512: 400
# Error fetching data for region KN149988.1:-90056-9944: 400
# Error fetching data for region KZ115960.1:-89592-10408: 400
# Error fetching data for region KN150501.1:-77608-22392: 400
# Error fetching data for region KN149718.1:-34753-65247: 400
# Error fetching data for region KZ115979.1:-87347-12653: 400
# Error fetching data for region KN150499.1:-88160-11840: 400
# Error fetching data for region KN149801.1:-95546-4454: 400
# Error fetching data for region KN149892.1:-75362-24638: 400
# Error fetching data for region KN149720.1:-89789-10211: 400
# Error fetching data for region KN150307.1:-90833-9167: 400
# Error fetching data for region KZ116037.1:-86752-13248: 400
# Error fetching data for region KN150628.1:-66094-33906: 400
# Error fetching data for region KN150629.1:-80396-19604: 400
# Error fetching data for region KN150708.1:-57323-42677: 400
# Error fetching data for region KN150709.1:-34630-65370: 400
# Error fetching data for region KN150710.1:-80371-19629: 400
# Error fetching data for region KN149754.1:-59786-40214: 400
# Error fetching data for region KN150372.1:-70440-29560: 400
# Error fetching data for region KN150472.1:-85414-14586: 400
# Error fetching data for region KN150585.1:-87570-12430: 400
# Error fetching data for region KN150586.1:-82612-17388: 400
# Error fetching data for region KN150587.1:-91539-8461: 400
# Error fetching data for region KN150290.1:-81752-18248: 400
# Error fetching data for region KN150292.1:-90016-9984: 400
# Error fetching data for region KN150636.1:-79487-20513: 400
# Error fetching data for region KN150386.1:-64100-35900: 400
# Error fetching data for region KN150528.1:-86862-13138: 400
# Error fetching data for region KN149746.1:-89100-10900: 400
# Error fetching data for region KN149899.1:-86368-13632: 400
# Error fetching data for region KN150677.1:-33044-66956: 400
# Error fetching data for region KN150622.1:-84189-15811: 400
# Error fetching data for region KZ115983.1:-89310-10690: 400
# Error fetching data for region KN150513.1:-89780-10220: 400
# Error fetching data for region KZ115954.1:-92319-7681: 400
# Error fetching data for region KZ116025.1:-96136-3864: 400
# Error fetching data for region KN150532.1:-78398-21602: 400
# Error fetching data for region KZ116023.1:-92125-7875: 400
# Error fetching data for region KN149896.1:-86898-13102: 400
# Error fetching data for region KN149897.1:-85956-14044: 400
# Error fetching data for region KN150167.1:-86534-13466: 400
# Error fetching data for region KZ115990.1:-91986-8014: 400
# Error fetching data for region KN150328.1:-82590-17410: 400
# Error fetching data for region KN150329.1:-86703-13297: 400
# Error fetching data for region KN150422.1:-84947-15053: 400
# Error fetching data for region KN149862.1:-88013-11987: 400
# Error fetching data for region KN150144.1:-85026-14974: 400
# Error fetching data for region KN148869.2:-81477-18523: 400
# Error fetching data for region KN150615.1:-90122-9878: 400
# Error fetching data for region KN149791.1:-82727-17273: 400
# Error fetching data for region KN150411.1:-79114-20886: 400
# Error fetching data for region KN150469.1:-85386-14614: 400
# Error fetching data for region KN149792.1:-88768-11232: 400
# Error fetching data for region KN150505.1:-60735-39265: 400
# Error fetching data for region KN150506.1:-85681-14319: 400
# Error fetching data for region KN149873.1:-98854-1146: 400
# Error fetching data for region KN149874.1:-94705-5295: 400
# Error fetching data for region KN150555.1:-90059-9941: 400
# Error fetching data for region KN149770.1:-87954-12046: 400
# Error fetching data for region KN149771.1:-85849-14151: 400
# Error fetching data for region KN150538.1:-87881-12119: 400
# Error fetching data for region KN150687.1:-86706-13294: 400
# Error fetching data for region KZ116012.1:-90501-9499: 400
# Error fetching data for region KN149810.1:-84957-15043: 400
# Error fetching data for region KN149811.1:-91280-8720: 400
# Error fetching data for region KZ116021.1:-82784-17216: 400
# Error fetching data for region KN150217.1:-86160-13840: 400
# Error fetching data for region KZ115989.1:-88618-11382: 400
# Error fetching data for region KN149946.1:-66929-33071: 400
# Error fetching data for region KN150380.1:-87856-12144: 400
# Error fetching data for region KN150491.1:-86999-13001: 400
# Error fetching data for region KN150152.1:-90652-9348: 400
# Error fetching data for region KN150012.1:-88002-11998: 400
# Error fetching data for region KN150089.1:-86896-13104: 400
# Error fetching data for region KN149960.1:-90765-9235: 400
# Error fetching data for region KN150374.1:-90225-9775: 400
# Error fetching data for region KN150546.1:-89149-10851: 400
# Error fetching data for region KN150221.1:-71878-28122: 400
# Error fetching data for region KN150477.1:-38307-61693: 400
# Error fetching data for region KN150478.1:-74187-25813: 400
# Error fetching data for region KN150060.1:-19766-80234: 400
# Error fetching data for region KN150061.1:-75952-24048: 400
# Error fetching data for region KN150225.1:-79571-20429: 400
# Error fetching data for region KN150614.1:-90981-9019: 400
# Error fetching data for region KN150508.1:-73186-26814: 400
# Error fetching data for region KN150193.1:-87420-12580: 400
# Error fetching data for region KN149843.1:-66742-33258: 400
# Error fetching data for region KZ116035.1:-98234-1766: 400
# Error fetching data for region KZ116013.1:-92978-7022: 400
# Error fetching data for region KZ116029.1:-67440-32560: 400
# Error fetching data for region KN150653.1:-44003-55997: 400
# Error fetching data for region KN150654.1:-81586-18414: 400
# Error fetching data for region KN150358.1:-90049-9951: 400
# Error fetching data for region KZ115980.1:-88556-11444: 400
# Error fetching data for region KN150599.1:-80981-19019: 400
# Error fetching data for region KZ115981.1:-87898-12102: 400
# Error fetching data for region KN149788.1:-91206-8794: 400
# Error fetching data for region KN149982.1:-68186-31814: 400
# Error fetching data for region KN150063.1:-79154-20846: 400
# Error fetching data for region KN150150.1:-90220-9780: 400
# Error fetching data for region KN150323.1:-81863-18137: 400
# Error fetching data for region KN149923.1:-63271-36729: 400
# Error fetching data for region KN149925.1:-70140-29860: 400
# Error fetching data for region KN149708.1:-79433-20567: 400
# Error fetching data for region KZ115998.1:-90931-9069: 400
# Error fetching data for region KN149758.1:-90485-9515: 400
# Error fetching data for region KN149769.1:-46952-53048: 400
# Error fetching data for region KZ115967.1:-97777-2223: 400
# Error fetching data for region KZ115974.1:-66321-33679: 400
# Error fetching data for region KN150428.1:-70784-29216: 400
# Error fetching data for region KN149996.1:-66472-33528: 400
# Error fetching data for region KN150451.1:-85080-14920: 400
# Error fetching data for region KN150452.1:-91655-8345: 400
# Error fetching data for region KN150453.1:-86409-13591: 400
# Error fetching data for region KZ115973.1:-92671-7329: 400
# Error fetching data for region KN150588.1:-85897-14103: 400
# Error fetching data for region KN150095.1:-90796-9204: 400
# Error fetching data for region KN150293.1:-59236-40764: 400
# Error fetching data for region KN150541.1:-87677-12323: 400
# Error fetching data for region KZ115997.1:-96082-3918: 400
# Error fetching data for region KN150542.1:-87833-12167: 400
# Error fetching data for region KN149907.1:-90130-9870: 400
# Error fetching data for region KN150342.1:-17410-82590: 400
# Error fetching data for region KN150028.1:-80483-19517: 400
# Error fetching data for region KN150029.1:-87585-12415: 400
# Error fetching data for region KZ116000.1:-84907-15093: 400
# Error fetching data for region KN150287.1:-88144-11856: 400
# Error fetching data for region KN150617.1:-9792-90208: 400
# Error fetching data for region KZ116047.1:-85749-14251: 400
# Error fetching data for region KN149827.1:-86445-13555: 400
# Error fetching data for region KZ116019.1:-65394-34606: 400
# Error fetching data for region KZ115986.1:-85854-14146: 400
# Error fetching data for region KN149819.1:-89790-10210: 400
# Error fetching data for region KN150102.1:-65569-34431: 400
# Error fetching data for region KN150113.1:-80690-19310: 400
# Error fetching data for region KN150576.1:-63871-36129: 400
# Error fetching data for region KZ115965.1:-91369-8631: 400
# Error fetching data for region KN150554.1:-90749-9251: 400
# Error fetching data for region KN149971.1:-88725-11275: 400
# Error fetching data for region KN149697.1:-59031-40969: 400
# Error fetching data for region KN150296.1:-89762-10238: 400
# Error fetching data for region KN150155.1:-89718-10282: 400
# Error fetching data for region KN150090.1:-87972-12028: 400
# Error fetching data for region KN150369.1:-88540-11460: 400
# Error fetching data for region KN150145.1:-90030-9970: 400
# Error fetching data for region KN150147.1:-92023-7977: 400
# Error fetching data for region KN149939.1:-23389-76611: 400
# Error fetching data for region KN150349.1:-70886-29114: 400
# Error fetching data for region KN150347.1:-48472-51528: 400
# Error fetching data for region KN149826.1:-9518-90482: 400
# Error fetching data for region KN150649.1:-18751-81249: 400
# Error fetching data for region KN149723.1:-44216-55784: 400
# Error fetching data for region KN149737.1:-72300-27700: 400
# Error fetching data for region KZ116057.1:-95118-4882: 400
# Error fetching data for region KN150418.1:-85070-14930: 400
# Error fetching data for region KN150282.1:-76242-23758: 400
# Error fetching data for region KN150317.1:-85134-14866: 400
# Error fetching data for region KN150172.1:-59366-40634: 400
# Error fetching data for region KN149804.1:-89852-10148: 400
# Error fetching data for region KN149805.1:-87568-12432: 400
# Error fetching data for region KN150467.1:-88798-11202: 400
# Error fetching data for region KN150242.1:-79937-20063: 400
# Error fetching data for region KZ115968.1:-92537-7463: 400
# Error fetching data for region KZ116020.1:-85066-14934: 400
# Error fetching data for region KZ115984.1:-97702-2298: 400
# Error fetching data for region KN150314.1:-87545-12455: 400
# Error fetching data for region KN150131.1:-29132-70868: 400
# Error fetching data for region KN149775.2:-73926-26074: 400
# Error fetching data for region KN149750.1:-86072-13928: 400
# Error fetching data for region KN150683.1:-83178-16822: 400
# Error fetching data for region KN150684.1:-75947-24053: 400
# Error fetching data for region KZ116006.1:-86862-13138: 400
# Error fetching data for region KN150140.2:-80267-19733: 400
# Error fetching data for region KN150252.1:-56867-43133: 400
# Error fetching data for region KN150325.1:-80475-19525: 400
# Error fetching data for region KN150616.1:-11301-88699: 400
# Error fetching data for region KN150195.1:-81079-18921: 400
# Error fetching data for region KN149968.1:-17010-82990: 400
# Error fetching data for region KN150224.1:-75846-24154: 400
# Error fetching data for region KN150517.1:-83829-16171: 400
# Error fetching data for region KN150297.1:-76528-23472: 400
# Error fetching data for region KN150049.1:-54992-45008: 400
# Error fetching data for region KN150265.1:-48445-51555: 400
# Error fetching data for region KN149806.1:-84843-15157: 400
# Error fetching data for region KZ116060.1:-92146-7854: 400
# Error fetching data for region KN150492.2:-69725-30275: 400
# Error fetching data for region KN150429.1:-82317-17683: 400
# Error fetching data for region KN150312.1:-82718-17282: 400
# Error fetching data for region KN149984.1:-3523-96477: 400
# Error fetching data for region KN149978.1:-83199-16801: 400
# Error fetching data for region KN149782.1:-63903-36097: 400
# Error fetching data for region KN149909.1:-59944-40056: 400
# Error fetching data for region KN150009.1:-82273-17727: 400
# Error fetching data for region KN150389.1:-89666-10334: 400
# Error fetching data for region KN150390.1:-80934-19066: 400
# Error fetching data for region KZ115994.1:-82175-17825: 400
# Error fetching data for region KN150675.1:-58142-41858: 400
# Error fetching data for region KN150105.1:-41938-58062: 400
# Error fetching data for region KZ116026.1:-85682-14318: 400
# Error fetching data for region KN149787.1:-60206-39794: 400
# Error fetching data for region KN150577.1:-86281-13719: 400
# Error fetching data for region KN149950.1:-94048-5952: 400
# Error fetching data for region KN149813.1:-40991-59009: 400
# Error fetching data for region KN149822.1:-97540-2460: 400
# Error fetching data for region KN149876.1:-88702-11298: 400
# Error fetching data for region KN150042.1:-69211-30789: 400
# Error fetching data for region KN150310.1:-79491-20509: 400
# Error fetching data for region KN150202.1:-84549-15451: 400
# Error fetching data for region KN150040.1:-80104-19896: 400
# Error fetching data for region KN150253.1:-96851-3149: 400
# Error fetching data for region KN150025.1:-73657-26343: 400
# Error fetching data for region KN150070.1:-85930-14070: 400
# Error fetching data for region KZ115962.1:-90672-9328: 400
# Error fetching data for region KN150300.1:-90511-9489: 400
# Error fetching data for region KN150301.1:-81336-18664: 400
# Error fetching data for region KN150361.1:-46376-53624: 400
# Error fetching data for region KN150236.1:-80685-19315: 400
# Error fetching data for region KZ116016.1:-94832-5168: 400
# Error fetching data for region KN150404.1:-81840-18160: 400
# Error fetching data for region KN150464.1:-75135-24865: 400
# Error fetching data for region KN150552.1:-25950-74050: 400
# Error fetching data for region KN149715.1:-80980-19020: 400
# Error fetching data for region KZ116032.1:-94127-5873: 400
# Error fetching data for region KN150661.1:-73750-26250: 400
# Error fetching data for region KN150032.1:-70454-29546: 400
# Error fetching data for region KZ115963.1:-94489-5511: 400
# Error fetching data for region KN150341.1:-68853-31147: 400
# Error fetching data for region KN150179.1:-52527-47473: 400
# Error fetching data for region KN150408.1:-62809-37191: 400
# Error fetching data for region KN150041.2:-33569-66431: 400
# Error fetching data for region KN150572.1:-71129-28871: 400
# Error fetching data for region KN150136.1:-50627-49373: 400
# Error fetching data for region KN150642.1:-44464-55536: 400
# Error fetching data for region KN150602.1:-77270-22730: 400
# Error fetching data for region KN149893.1:-72005-27995: 400
# Error fetching data for region KN150306.1:-63272-36728: 400
# Error fetching data for region KN150645.1:-77161-22839: 400
# Error fetching data for region KN150360.1:-84361-15639: 400
# Error fetching data for region KN149979.1:-77166-22834: 400
# Error fetching data for region KN150184.1:-83688-16312: 400
# Error fetching data for region KN150218.1:-84646-15354: 400
# Error fetching data for region KN150711.1:-88060-11940: 400
# Error fetching data for region KN150664.1:-90410-9590: 400
# Error fetching data for region KN150013.1:-91512-8488: 400
# Error fetching data for region KN150488.1:-82418-17582: 400
# Error fetching data for region KN149905.1:-85944-14056: 400
# Error fetching data for region KZ116040.1:-96946-3054: 400
# Error fetching data for region KN150058.1:-78652-21348: 400
# Error fetching data for region KN150111.1:-70069-29931: 400
# Error fetching data for region KN149809.1:-97999-2001: 400
# Error fetching data for region KZ115969.1:-88904-11096: 400
# Error fetching data for region KN150132.1:-86001-13999: 400
# Error fetching data for region KN149880.1:-35111-64889: 400
# Error fetching data for region KZ116053.1:-83534-16466: 400
# Error fetching data for region KN149803.1:-83982-16018: 400
# Error fetching data for region KN150455.1:-26464-73536: 400
# Error fetching data for region KZ116007.1:-88951-11049: 400
# Error fetching data for region KN149951.1:-95000-5000: 400
# Error fetching data for region KN150201.1:-90520-9480: 400
# Error fetching data for region KN150182.1:-88265-11735: 400
# Error fetching data for region KN149998.1:-25276-74724: 400
# Error fetching data for region KN150527.1:-79120-20880: 400
# Error fetching data for region KZ116052.1:-97974-2026: 400
# Error fetching data for region KN150416.1:-66165-33835: 400
# Error fetching data for region KN150573.1:-73396-26604: 400
# Error fetching data for region KN149745.1:-91850-8150: 400
# Error fetching data for region KN149832.1:-87517-12483: 400
# Error fetching data for region KN150015.1:-66559-33441: 400
# Error fetching data for region KN150494.1:-89892-10108: 400
# Error fetching data for region KN149711.1:-88527-11473: 400
# Error fetching data for region KN149713.1:-89906-10094: 400
# Error fetching data for region KN150148.1:-55411-44589: 400
# Error fetching data for region KN150260.1:-87682-12318: 400
# Error fetching data for region KN150405.1:-23081-76919: 400
# Error fetching data for region KN150545.1:-82454-17546: 400
# Error fetching data for region KN150530.1:-92701-7299: 400
# Error fetching data for region KN150031.1:-39101-60899: 400
# Error fetching data for region KN150279.1:-88598-11402: 400
# Error fetching data for region KN150331.1:-55032-44968: 400
# Error fetching data for region KN150308.1:-81093-18907: 400
# Error fetching data for region KN150441.1:-87561-12439: 400
# Error fetching data for region KN150154.1:-78305-21695: 400
# Error fetching data for region KN147552.2:-75627-24373: 400
# Error fetching data for region KN149997.1:-93704-6296: 400
# Error fetching data for region KN149795.1:-65385-34615: 400
# Error fetching data for region KN149959.1:-40726-59274: 400
# Error fetching data for region KN150117.1:-51457-48543: 400
# Error fetching data for region KN149762.1:-82064-17936: 400
# Error fetching data for region KN148828.2:-86678-13322: 400
# Error fetching data for region KZ116008.1:-82774-17226: 400
# Error fetching data for region KN150419.1:-85886-14114: 400
# Error fetching data for region KN150426.1:-78501-21499: 400
# Error fetching data for region KN149725.1:-30171-69829: 400
# Error fetching data for region KN149943.1:-70392-29608: 400
# Error fetching data for region KN150644.1:-79466-20534: 400
# Error fetching data for region KN149835.1:-74139-25861: 400
# Error fetching data for region KZ116018.1:-88994-11006: 400
# Error fetching data for region KN150536.1:-82092-17908: 400
# Error fetching data for region KN150127.1:-66698-33302: 400
# Error fetching data for region KN150335.1:-55496-44504: 400
# Error fetching data for region KN149850.1:-66599-33401: 400
# Error fetching data for region KN150371.1:-86164-13836: 400
# Error fetching data for region KN149721.1:-74538-25462: 400
# Error fetching data for region KN150570.1:-57721-42279: 400
# Error fetching data for region KN149760.1:-53395-46605: 400
# Error fetching data for region KZ116030.1:-96448-3552: 400
# Error fetching data for region KN150074.1:-71347-28653: 400
# Error fetching data for region KN150228.1:-82939-17061: 400
# Error fetching data for region KN150215.1:-98763-1237: 400
# Error fetching data for region KN150216.1:-98980-1020: 400
# Error fetching data for region KN150030.1:-42926-57074: 400
# Error fetching data for region KN150485.1:-92652-7348: 400
# Error fetching data for region KZ115948.1:-92105-7895: 400
# Error fetching data for region KN150023.1:-77847-22153: 400
# Error fetching data for region KN150159.1:-64771-35229: 400
# Error fetching data for region KN149924.1:-76605-23395: 400
# Error fetching data for region KN149700.1:-59950-40050: 400
# Error fetching data for region KN150166.1:-50543-49457: 400
# Error fetching data for region KN150038.1:-28674-71326: 400
# Error fetching data for region KN150606.1:-48304-51696: 400
# Error fetching data for region KN149912.1:-22021-77979: 400
# Error fetching data for region KN149921.1:-71746-28254: 400
# Error fetching data for region KN150475.1:-82483-17517: 400
# Error fetching data for region KZ115987.1:-65272-34728: 400
# Error fetching data for region KN150319.1:-84193-15807: 400
# Error fetching data for region KZ116034.1:-66385-33615: 400
# Error fetching data for region KN150387.1:-84785-15215: 400
# Error fetching data for region KN149970.1:-82489-17511: 400
# Error fetching data for region KN150626.1:-67150-32850: 400
# Error fetching data for region KN150336.1:-51328-48672: 400
# Error fetching data for region KN150668.1:-78144-21856: 400
# Error fetching data for region KN149938.1:-87545-12455: 400
# Error fetching data for region KN150056.1:-70551-29449: 400
# Error fetching data for region KN150382.1:-85926-14074: 400
# Error fetching data for region KN150130.1:-90075-9925: 400
# Error fetching data for region KN150285.1:-74639-25361: 400
# Error fetching data for region KZ116033.1:-72897-27103: 400
# Error fetching data for region KN150133.2:-46544-53456: 400
# Error fetching data for region KN149710.1:-49026-50974: 400
# Error fetching data for region KN150432.1:-8990-91010: 400
# Error fetching data for region KN150357.1:-72674-27326: 400
# Error fetching data for region KN150234.1:-81489-18511: 400
# Error fetching data for region KZ115961.1:-98186-1814: 400
# Error fetching data for region KN150333.1:-87725-12275: 400
# Error fetching data for region KZ116005.1:-98080-1920: 400
# Error fetching data for region KN149955.1:-80242-19758: 400
# Error fetching data for region KN149727.1:-75129-24871: 400
# Error fetching data for region KN149931.1:-93297-6703: 400
# Error fetching data for region KN150594.1:-80618-19382: 400
# Error fetching data for region KN150500.1:-80134-19866: 400
# Error fetching data for region KN149761.1:-85205-14795: 400
# Error fetching data for region KN150564.1:-82291-17709: 400
# Error fetching data for region KN150175.1:-75388-24612: 400
# Error fetching data for region KN150652.1:-81925-18075: 400
# Error fetching data for region KN150385.1:-62945-37055: 400
# Error fetching data for region KN149879.1:-88107-11893: 400
# Error fetching data for region KN150313.1:-79345-20655: 400
# Error fetching data for region KZ115956.1:-88983-11017: 400
# Error fetching data for region KN149834.1:-82657-17343: 400
# Error fetching data for region KN149765.1:-70803-29197: 400
# Error fetching data for region KN149800.1:-57951-42049: 400
# Error fetching data for region KN150399.1:-80638-19362: 400
# Error fetching data for region KN149751.1:-84152-15848: 400
# Error fetching data for region KN150550.1:-85085-14915: 400
# Error fetching data for region KN149913.1:-83513-16487: 400
# Error fetching data for region KN149705.1:-72074-27926: 400
# Error fetching data for region KN150120.1:-72489-27511: 400
# Error fetching data for region KN150703.1:-51991-48009: 400
# Error fetching data for region KN149812.1:-48581-51419: 400
# Error fetching data for region KN150055.1:-67439-32561: 400
# Error fetching data for region KN150476.1:-40789-59211: 400
# Error fetching data for region KN149829.1:-72677-27323: 400
# Error fetching data for region KN149816.1:-89872-10128: 400
# Error fetching data for region KN150115.1:-81324-18676: 400
# Error fetching data for region KN149777.1:-98447-1553: 400
# Error fetching data for region KN149772.1:-86727-13273: 400
# Error fetching data for region KN149722.1:-86603-13397: 400
# Error fetching data for region KZ115951.1:-98540-1460: 400
# Error fetching data for region KN150421.1:-85049-14951: 400
# Error fetching data for region KZ116022.1:-98081-1919: 400
# Error fetching data for region KN150662.1:-82180-17820: 400
# Error fetching data for region KN149927.1:-88050-11950: 400
# Error fetching data for region KN150353.1:-80369-19631: 400
# Error fetching data for region KN149853.1:-87183-12817: 400
# Error fetching data for region KN150625.1:-77514-22486: 400
# Error fetching data for region KN150345.1:-82988-17012: 400
# Error fetching data for region KN150181.1:-67239-32761: 400
# Error fetching data for region KZ116039.1:-87539-12461: 400
# Error fetching data for region KZ115953.1:-98718-1282: 400
# Error fetching data for region KN150613.1:-84261-15739: 400
# Error fetching data for region KN149999.1:-85929-14071: 400
# Error fetching data for region KN150458.1:-82519-17481: 400
# Error fetching data for region KN150526.1:-84487-15513: 400
# Error fetching data for region KN149976.1:-88142-11858: 400
# Error fetching data for region KN150462.1:-75377-24623: 400
# Error fetching data for region KZ116062.1:-93077-6923: 400
# Error fetching data for region KN150243.2:-54036-45964: 400
# Error fetching data for region KN150137.1:-63221-36779: 400
# Error fetching data for region KN149871.1:-77447-22553: 400
# Error fetching data for region KN150363.1:-77234-22766: 400
# Error fetching data for region KN149895.1:-7070-92930: 400
# Error fetching data for region KN150000.1:-30263-69737: 400
# Error fetching data for region KN150529.1:-18054-81946: 400
# Error fetching data for region KN150579.1:-76414-23586: 400
# Error fetching data for region KN149838.1:-70975-29025: 400
# Error fetching data for region KN150232.1:-46460-53540: 400
# Error fetching data for region KN150630.1:-13579-86421: 400
# Error fetching data for region KZ116043.1:-80661-19339: 400
# Error fetching data for region KZ115985.1:-85909-14091: 400
# Error fetching data for region KN150670.1:-22007-77993: 400
# Error fetching data for region KN150685.1:-86691-13309: 400
# Error fetching data for region KN150156.1:-66753-33247: 400
# Error fetching data for region KN150557.1:-58541-41459: 400
# Error fetching data for region KN150062.1:-64962-35038: 400
# Error fetching data for region KN150068.1:-37275-62725: 400
# Error fetching data for region KN149993.1:-83079-16921: 400
# Error fetching data for region KN150562.1:-77125-22875: 400
# Error fetching data for region KN149814.1:-74122-25878: 400
# Error fetching data for region KN150085.1:-70823-29177: 400
# Error fetching data for region KN149958.1:-56927-43073: 400
# Error fetching data for region KN150598.1:-87501-12499: 400
# Error fetching data for region KN150014.1:-86412-13588: 400
# Error fetching data for region KN149953.1:-53782-46218: 400
# Error fetching data for region KN150646.1:-21924-78076: 400
# Error fetching data for region KN150454.1:-81521-18479: 400
# Error fetching data for region KN149756.1:-88215-11785: 400
# Error fetching data for region KN150203.1:-75996-24004: 400
# Error fetching data for region KZ116063.1:-97399-2601: 400
# Error fetching data for region KN150466.1:-58681-41319: 400
# Error fetching data for region KN150635.1:-72053-27947: 400
# Error fetching data for region KZ115950.1:-88849-11151: 400
# Error fetching data for region KN149973.1:-64445-35555: 400
# Error fetching data for region KN149974.1:-80404-19596: 400
# Error fetching data for region KN149935.1:-90770-9230: 400
# Error fetching data for region KN150186.1:-76077-23923: 400
# Error fetching data for region KN150240.1:-68277-31723: 400
# Error fetching data for region KN150270.1:-77715-22285: 400
# Error fetching data for region KN150098.1:-31721-68279: 400
# Error fetching data for region KN150678.1:-92448-7552: 400
# Error fetching data for region KN150403.1:-65303-34697: 400
# Error fetching data for region KN150525.1:-99350-650: 400
# Error fetching data for region KN149872.1:-87778-12222: 400
# Error fetching data for region KN149796.1:-74365-25635: 400
# Error fetching data for region KN150118.1:-45506-54494: 400
# Error fetching data for region KN150582.1:-87604-12396: 400
# Error fetching data for region KN150534.1:-82339-17661: 400
# Error fetching data for region KN150246.1:-84635-15365: 400
# Error fetching data for region KN150551.1:-90565-9435: 400
# Error fetching data for region KN150671.1:-86474-13526: 400
# Error fetching data for region KN150204.1:-4851-95149: 400
# Error fetching data for region KN149789.1:-87010-12990: 400
# Error fetching data for region KN149719.1:-52469-47531: 400
# Error fetching data for region KN150631.1:-63676-36324: 400
# Error fetching data for region KN150431.1:-10341-89659: 400
# Error fetching data for region KN150125.1:-16685-83315: 400
# Error fetching data for region KN149780.1:-80282-19718: 400
# Error fetching data for region KN150504.1:-87906-12094: 400
# Error fetching data for region KN150493.1:-64425-35575: 400
# Error fetching data for region KN150483.1:-82668-17332: 400
# Error fetching data for region KN150122.1:-32466-67534: 400
# Error fetching data for region KN149944.1:-75091-24909: 400
# Error fetching data for region KN149828.1:-88586-11414: 400
# Error fetching data for region KN150039.1:-96537-3463: 400
# Error fetching data for region KN150187.1:-80821-19179: 400
# Error fetching data for region KN150077.1:-48640-51360: 400
# Error fetching data for region KN150547.1:-62580-37420: 400
# Error fetching data for region KN149889.1:-89834-10166: 400
# Error fetching data for region KN149890.1:-87971-12029: 400
# Error fetching data for region KN150589.1:-81043-18957: 400
# Error fetching data for region KN150337.1:-79740-20260: 400
# Error fetching data for region KN150640.1:-79110-20890: 400
# Error fetching data for region KN149733.1:-78363-21637: 400
# Error fetching data for region KN149861.1:-85664-14336: 400
# Error fetching data for region KN149774.1:-87663-12337: 400
# Error fetching data for region KN149854.1:-93633-6367: 400
# Error fetching data for region KN150699.1:-73900-26100: 400
# Error fetching data for region KN150191.1:-57697-42303: 400
# Error fetching data for region KN150340.1:-71259-28741: 400
# Error fetching data for region KN149716.1:-57771-42229: 400
# Error fetching data for region KN150553.1:-85968-14032: 400
# Error fetching data for region KN150128.1:-87738-12262: 400
# Error fetching data for region KN149856.1:-64670-35330: 400
# Error fetching data for region KZ116046.1:-94193-5807: 400
# Error fetching data for region KN149965.1:-85210-14790: 400
# Error fetching data for region KZ115966.1:-89300-10700: 400
# Error fetching data for region KN149844.1:-89799-10201: 400
# Error fetching data for region KN149779.1:-78336-21664: 400
# Error fetching data for region KN150164.1:-88700-11300: 400
# Error fetching data for region KN150318.1:-97420-2580: 400
# Error fetching data for region KN150623.1:-98874-1126: 400
# Error fetching data for region KN149740.1:-98735-1265: 400
# Error fetching data for region KN150170.1:-44284-55716: 400
# Error fetching data for region KN149757.1:-83855-16145: 400
# Error fetching data for region KN150368.1:-81509-18491: 400
# Error fetching data for region KN150004.2:-86941-13059: 400
# Error fetching data for region KN150212.1:-81068-18932: 400
# Error fetching data for region KN150412.1:-90395-9605: 400
# Error fetching data for region KN149785.1:-98423-1577: 400
# Error fetching data for region KN149860.1:-82592-17408: 400
# Error fetching data for region KN149701.1:-96240-3760: 400
# Error fetching data for region KN150689.1:-80450-19550: 400
# Error fetching data for region KN149717.1:-52411-47589: 400
# Error fetching data for region KN150540.1:-84712-15288: 400
# Error fetching data for region KN150255.2:-70632-29368: 400
# Error fetching data for region KN150459.1:-54397-45603: 400
# Error fetching data for region KN149753.1:-69751-30249: 400
# Error fetching data for region KN149961.1:-79400-20600: 400
# Error fetching data for region KN150682.1:-84810-15190: 400
# Error fetching data for region KN150035.1:-61914-38086: 400
# Error fetching data for region KN150226.1:-74707-25293: 400
# Error fetching data for region KN150468.1:-74619-25381: 400
# Error fetching data for region KN150059.1:-83412-16588: 400
# Error fetching data for region KN150398.1:-60443-39557: 400
# Error fetching data for region KN150106.1:-43476-56524: 400
# Error fetching data for region KN149714.1:-25378-74622: 400
# Error fetching data for region KN149786.1:-98255-1745: 400
# Error fetching data for region KN150634.1:-83980-16020: 400
# Error fetching data for region KZ115975.1:-98332-1668: 400
# Error fetching data for region KN150355.1:-93269-6731: 400
# Error fetching data for region KN150659.1:-88173-11827: 400
# Error fetching data for region KN150365.1:-89231-10769: 400
# Error fetching data for region KN149885.1:-98653-1347: 400
# Error fetching data for region KZ116045.1:-97971-2029: 400
# Error fetching data for region KN149867.1:-98486-1514: 400
# Error fetching data for region KZ116003.1:-84895-15105: 400
# Error fetching data for region KZ115992.1:-98750-1250: 400
# Error fetching data for region KZ115957.1:-96967-3033: 400
# Error fetching data for region KN149926.1:-96312-3688: 400
# Error fetching data for region KN150609.1:-62587-37413: 400
# Error fetching data for region KN149755.1:-88059-11941: 400
# Error fetching data for region KN150286.1:-90932-9068: 400
# Error fetching data for region KN150495.1:-71840-28160: 400
# Error fetching data for region KN150641.1:-85222-14778: 400
# Error fetching data for region KN150254.1:-87856-12144: 400
# Error fetching data for region KN150205.1:-97380-2620: 400
# Error fetching data for region KZ115959.1:-97924-2076: 400
# Error fetching data for region KN149937.1:-85890-14110: 400
# Error fetching data for region KN150701.1:-98867-1133: 400
# Error fetching data for region KN150037.1:-97134-2866: 400
# Error fetching data for region KZ116038.1:-98572-1428: 400
# Error fetching data for region KN149956.1:-98111-1889: 400
# Error fetching data for region KN150583.1:-98082-1918: 400
# Error fetching data for region KN150543.1:-97657-2343: 400
# Error fetching data for region KN150338.1:-98858-1142: 400
# Error fetching data for region KN149742.1:-97329-2671: 400
# Error fetching data for region KN149824.1:-97643-2357: 400
# Error fetching data for region KN150206.1:-97948-2052: 400
# Error fetching data for region KN150051.1:-98005-1995: 400
# Error fetching data for region KN149957.1:-98906-1094: 400
# Error fetching data for region KZ116051.1:-97582-2418: 400
# Error fetching data for region KN150237.1:-98268-1732: 400
# Error fetching data for region KN150489.1:-73261-26739: 400
# Error fetching data for region KN149741.1:-78059-21941: 400
# Error fetching data for region KN150284.1:-81869-18131: 400
# Error fetching data for region KN149917.1:-96169-3831: 400
# Error fetching data for region KZ115978.1:-95133-4867: 400
# Error fetching data for region KN148038.2:-82415-17585: 400
# Error fetching data for region KN150057.1:-89264-10736: 400
# Error fetching data for region KN150481.1:-98992-1008: 400
# Error fetching data for region KN150465.1:-98235-1765: 400
# Error fetching data for region KN150392.1:-87931-12069: 400
# Error fetching data for region KN150522.1:-87954-12046: 400
# Error fetching data for region KZ115993.1:-82293-17707: 400
# Error fetching data for region KN150052.1:-84057-15943: 400
# Error fetching data for region KN150697.1:-87291-12709: 400
# Error fetching data for region KN150632.1:-88373-11627: 400
# Error fetching data for region KN150514.1:-80609-19391: 400
# Error fetching data for region KN150698.1:-68017-31983: 400
# Error fetching data for region KN149729.1:-94392-5608: 400
# Error fetching data for region KN150219.1:-83328-16672: 400
# Error fetching data for region KN150199.1:-83436-16564: 400
# Error fetching data for region KN150406.1:-82785-17215: 400
# Error fetching data for region KN150561.1:-77762-22238: 400
# Error fetching data for region KN150592.1:-50000-50000: 400
# Error fetching data for region KN150324.1:-75968-24032: 400
# Error fetching data for region KN150596.1:-39153-60847: 400
# Error fetching data for region KN149883.1:-87566-12434: 400
# Error fetching data for region KN150575.1:-88916-11084: 400
# Error fetching data for region KN150366.1:-89943-10057: 400
# Error fetching data for region KZ115977.1:-98083-1917: 400
# Error fetching data for region KN149735.1:-94253-5747: 400
# Error fetching data for region KN150354.1:-98548-1452: 400
# Error fetching data for region KN150233.1:-97754-2246: 400
# Error fetching data for region KN150437.1:-98738-1262: 400
# Error fetching data for region KN150112.1:-96577-3423: 400
# Error fetching data for region KN150413.1:-84922-15078: 400
# Error fetching data for region KN150633.1:-80442-19558: 400
# Error fetching data for region KN150185.1:-91349-8651: 400
# Error fetching data for region KN149841.1:-89915-10085: 400
# Error fetching data for region KN150486.1:-91428-8572: 400
# Error fetching data for region KN150194.1:-86371-13629: 400
# Error fetching data for region KN150440.1:-98807-1193: 400
# Error fetching data for region KN150180.1:-98128-1872: 400
# Error fetching data for region KZ116058.1:-95862-4138: 400
# Error fetching data for region KN150515.1:-98187-1813: 400
# Error fetching data for region KZ116036.1:-98081-1919: 400
# Error fetching data for region KN149855.1:-76835-23165: 400
# Error fetching data for region KN150086.1:-98361-1639: 400
# Error fetching data for region KN149878.1:-92453-7547: 400
# Error fetching data for region KN149707.2:-92545-7455: 400
# ...
# Error fetching data for region KN150100.1:-90763-9237: 400
# Error fetching data for region KZ115982.1:-78322-21678: 400
# Error fetching data for region KZ116001.1:-86277-13723: 400
# Error fetching data for region KN149724.1:-88151-11849: 400
# Error fetching data for region KN150523.1:-80996-19004: 400
# Error fetching data for region KN150521.1:-79104-20896: 400
# Error fetching data for region KN150034.1:-98081-1919: 400
# Error fetching data for region KN150103.1:-95910-4090: 400
# Error fetching data for region KN150076.1:-85575-14425: 400
# Error fetching data for region KN149823.1:-85966-14034: 400
# Error fetching data for region KN150544.1:-98802-1198: 400
# Error fetching data for region KN149798.1:-98010-1990: 400
# Error fetching data for region KN150593.1:-85647-14353: 400
# Error fetching data for region KN150565.1:-79536-20464: 400
# Error fetching data for region KN150249.1:-87739-12261: 400
# Error fetching data for region KN149908.1:-87200-12800: 400
# Error fetching data for region KN150407.1:-68186-31814: 400
# Error fetching data for region KN150067.1:-72675-27325: 400
# Error fetching data for region KN150289.1:-77794-22206: 400
# Error fetching data for region KN149706.1:-66721-33279: 400
# Error fetching data for region KN150189.1:-61132-38868: 400
# Error fetching data for region KN149840.1:-53136-46864: 400
# Error fetching data for region KZ116010.1:-93058-6942: 400
# Error fetching data for region KN149857.1:-89868-10132: 400
# Error fetching data for region KN150019.2:-80166-19834: 400
# Error fetching data for region KN150267.1:-22222-77778: 400
# Error fetching data for region KN150362.1:-82855-17145: 400
# Error fetching data for region KN150603.1:-1720-98280: 400
# Error fetching data for region KN150176.1:-30939-69061: 400
# Error fetching data for region KN150518.1:-59606-40394: 400
# Error fetching data for region KN150160.1:-82176-17824: 400
# Error fetching data for region KN150022.1:-23462-76538: 400
# Error fetching data for region KN150430.1:-83548-16452: 400
# Error fetching data for region KN149815.1:-66663-33337: 400
# Error fetching data for region KN150168.1:-71618-28382: 400
# Error fetching data for region KN150676.1:-48326-51674: 400
# Error fetching data for region KN149881.1:-89264-10736: 400
# Error fetching data for region KN149949.1:-35874-64126: 400
# Error fetching data for region KN150315.1:-79576-20424: 400
# Error fetching data for region KN150679.1:-85935-14065: 400
# Error fetching data for region KN150621.1:-98796-1204: 400
# Error fetching data for region KN149783.1:-88108-11892: 400
# Error fetching data for region KN149914.1:-81759-18241: 400
# Error fetching data for region KN150334.1:-77458-22542: 400
# Error fetching data for region KN150141.1:-82883-17117: 400
# Error fetching data for region KN149818.1:-74058-25942: 400
# Error fetching data for region KN150595.1:-87493-12507: 400
# Error fetching data for region KN150008.1:-84428-15572: 400
# Error fetching data for region KN150330.1:-71560-28440: 400
# Error fetching data for region KN150471.1:-23337-76663: 400
# Error fetching data for region KN150574.1:-81501-18499: 400
# Error fetching data for region KN149967.1:-91388-8612: 400
# Error fetching data for region KN150064.1:-85402-14598: 400
# Error fetching data for region KN149882.1:-92351-7649: 400
# Error fetching data for region KZ116009.1:-98605-1395: 400
# Error fetching data for region KN149767.1:-69126-30874: 400
# Error fetching data for region KN150639.1:-72380-27620: 400
# Error fetching data for region KN149888.1:-82883-17117: 400
# Error fetching data for region KN150123.1:-48022-51978: 400
# Error fetching data for region KN149859.1:-46694-53306: 400
# Error fetching data for region KN150220.1:-70375-29625: 400
# Error fetching data for region KN150126.1:-75153-24847: 400
# Error fetching data for region KN149763.1:-80356-19644: 400
# Error fetching data for region KN150033.1:-43552-56448: 400
# Error fetching data for region KN150434.1:-87947-12053: 400
# Error fetching data for region KN150078.1:-87902-12098: 400
# Error fetching data for region KZ116048.1:-98644-1356: 400
# Error fetching data for region KN150473.1:-98715-1285: 400
# Error fetching data for region KN149981.1:-87189-12811: 400
# Error fetching data for region KZ116017.1:-97135-2865: 400
# Error fetching data for region KN150229.1:-98749-1251: 400
# Error fetching data for region KN150560.1:-97699-2301: 400
# Error fetching data for region KN150680.1:-86621-13379: 400
# Error fetching data for region KN150044.1:-90903-9097: 400
# Error fetching data for region KN149743.1:-78977-21023: 400
# Error fetching data for region KN150110.1:-90196-9804: 400
# Error fetching data for region KN149906.1:-61013-38987: 400
# Error fetching data for region KN150558.1:-87885-12115: 400
# Error fetching data for region KN150559.1:-73420-26580: 400
# Error fetching data for region KN149940.1:-88113-11887: 400
# Error fetching data for region KN149941.1:-86393-13607: 400
# Error fetching data for region KN150322.1:-80356-19644: 400
# Error fetching data for region KN150311.1:-84253-15747: 400
# Error fetching data for region KN150663.1:-11392-88608: 400
# Error fetching data for region KZ115958.1:-83850-16150: 400
# Error fetching data for region KN150104.1:-46812-53188: 400
# Error fetching data for region KN149766.1:-85336-14664: 400
# Error fetching data for region KN150079.1:-53200-46800: 400
# Error fetching data for region KN150516.1:-50661-49339: 400
# Error fetching data for region KN149916.1:-95707-4293: 400
# Error fetching data for region KN150278.1:-69022-30978: 400
# Error fetching data for region KN149919.1:-78927-21073: 400
# Error fetching data for region KN150248.1:-81727-18273: 400
# Error fetching data for region KN150264.1:-83045-16955: 400
# Error fetching data for region KN150017.1:-74364-25636: 400
# Error fetching data for region KN149932.1:-10479-89521: 400
# Error fetching data for region KN149738.1:-89397-10603: 400
# Error fetching data for region KN149739.1:-48390-51610: 400
# Error fetching data for region KN149903.1:-88682-11318: 400
# Error fetching data for region KN149904.1:-10844-89156: 400
# Error fetching data for region KN150591.1:-91183-8817: 400
# Error fetching data for region MT:-83404-16596: 400
# Protein-coding genes near telomeric regions with external gene names and location:
# Chromosome KZ116065.1: Gene ID ENSDARG00000102423, External Gene Name KYAT3, Location Start
# Chromosome KN150173.1: Gene ID ENSDARG00000108505, External Gene Name MMD2, Location Start
# Chromosome KN150350.1: Gene ID ENSDARG00000104175, External Gene Name USP30, Location Start
# Chromosome KN150490.1: Gene ID ENSDARG00000103225, External Gene Name UBLCP1, Location Start
# Chromosome KN149995.1: Gene ID ENSDARG00000099196, External Gene Name CPLX3, Location Start
# Chromosome KN149948.1: Gene ID ENSDARG00000104293, External Gene Name mhc1zka, Location End
# Chromosome KN149702.1: Gene ID ENSDARG00000101020, External Gene Name KHDRBS3, Location End
# Chromosome KN149702.1: Gene ID ENSDARG00000101020, External Gene Name KHDRBS3, Location End
# Chromosome KN150165.1: Gene ID ENSDARG00000099178, External Gene Name ABCD2, Location Start
# Chromosome KZ115991.1: Gene ID ENSDARG00000116774, External Gene Name PCNP, Location Start
# Chromosome KZ116023.1: Gene ID ENSDARG00000113796, External Gene Name zgc:153137, Location Start
# Chromosome KN149874.1: Gene ID ENSDARG00000099481, External Gene Name ttc8, Location Start
# Chromosome KN150425.1: Gene ID ENSDARG00000101195, External Gene Name cyp1c1, Location End
# Chromosome KN150614.1: Gene ID ENSDARG00000100453, External Gene Name GALNT10, Location Start
# Chromosome KN149843.1: Gene ID ENSDARG00000098861, External Gene Name si:dkey-71b5.6, Location Start
# Chromosome KZ116047.1: Gene ID ENSDARG00000113721, External Gene Name HPDL, Location Start
# Chromosome KN150314.1: Gene ID ENSDARG00000103248, External Gene Name FAM167A, Location Start
# Chromosome KN150131.1: Gene ID ENSDARG00000102421, External Gene Name acp7, Location Start
# Chromosome KN150265.1: Gene ID ENSDARG00000102210, External Gene Name KCNIP1, Location Start
# Chromosome KN150158.1: Gene ID ENSDARG00000103190, External Gene Name psmd2, Location Start
# Chromosome KN150158.1: Gene ID ENSDARG00000103190, External Gene Name psmd2, Location Start
# Chromosome KZ115962.1: Gene ID ENSDARG00000110510, External Gene Name YBEY, Location Start
# Chromosome KN149790.1: Gene ID ENSDARG00000098186, External Gene Name TMEM19, Location End
# Chromosome KN150642.1: Gene ID ENSDARG00000099564, External Gene Name atoh1b, Location Start
# Chromosome KN150013.1: Gene ID ENSDARG00000099151, External Gene Name wbp11, Location Start
# Chromosome KN150487.1: Gene ID ENSDARG00000104567, External Gene Name KDM5A, Location Start
# Chromosome KZ116053.1: Gene ID ENSDARG00000109563, External Gene Name LSM10, Location Start
# Chromosome KN150015.1: Gene ID ENSDARG00000100651, External Gene Name PDCL3, Location Start
# Chromosome KN150230.1: Gene ID ENSDARG00000105121, External Gene Name FAM135B, Location Start
# Chromosome KN150545.1: Gene ID ENSDARG00000100810, External Gene Name CORO7, Location Start
# Chromosome KN149943.1: Gene ID ENSDARG00000100846, External Gene Name fgf21, Location Start
# Chromosome KZ116018.1: Gene ID ENSDARG00000113433, External Gene Name HYCC2, Location Start
# Chromosome KN150030.1: Gene ID ENSDARG00000106760, External Gene Name golim4a, Location Start
# Chromosome KZ116034.1: Gene ID ENSDARG00000099889, External Gene Name dusp27, Location Start
# Chromosome KN150432.1: Gene ID ENSDARG00000098523, External Gene Name NCAM2, Location Start
# Chromosome KN150550.1: Gene ID ENSDARG00000098241, External Gene Name fanca, Location Start
# Chromosome KN149816.1: Gene ID ENSDARG00000101434, External Gene Name slc39a3, Location Start
# Chromosome KN150115.1: Gene ID ENSDARG00000099205, External Gene Name RAB19, Location Start
# Chromosome KN150353.1: Gene ID ENSDARG00000104516, External Gene Name POLR3D, Location Start
# Chromosome KN150000.1: Gene ID ENSDARG00000104937, External Gene Name PTPRD, Location Start
# Chromosome KN150326.1: Gene ID ENSDARG00000104276, External Gene Name EIF2AK4, Location End
# Chromosome KN150326.1: Gene ID ENSDARG00000104276, External Gene Name EIF2AK4, Location End
# Chromosome KZ116043.1: Gene ID ENSDARG00000109774, External Gene Name FH, Location Start
# Chromosome KN150191.1: Gene ID ENSDARG00000111528, External Gene Name PITPNM2, Location Start
# Chromosome KN150128.1: Gene ID ENSDARG00000102302, External Gene Name WDR48, Location Start
# Chromosome KN149779.1: Gene ID ENSDARG00000099279, External Gene Name ift27, Location Start
# Chromosome KN149779.1: Gene ID ENSDARG00000102376, External Gene Name cacng2b, Location Start
# Chromosome KN150051.1: Gene ID ENSDARG00000101098, External Gene Name LAMP5, Location Start
# Chromosome KN149729.1: Gene ID ENSDARG00000111822, External Gene Name RAMP3, Location Start
# Chromosome KN149735.1: Gene ID ENSDARG00000102207, External Gene Name zgc:86738, Location Start
# Chromosome KN150086.1: Gene ID ENSDARG00000103574, External Gene Name RHO, Location Start
# Chromosome KN149707.2: Gene ID ENSDARG00000099389, External Gene Name cdo1, Location Start
# Chromosome KZ115982.1: Gene ID ENSDARG00000079363, External Gene Name lrig3, Location Start
# Chromosome KN149818.1: Gene ID ENSDARG00000099653, External Gene Name PSMD2, Location Start
# Chromosome KN149859.1: Gene ID ENSDARG00000103399, External Gene Name SLC44A2, Location Start
# Chromosome KN150680.1: Gene ID ENSDARG00000104467, External Gene Name bglapl, Location Start
# Chromosome KN150322.1: Gene ID ENSDARG00000100478, External Gene Name TULP1, Location Start
# Chromosome KN150311.1: Gene ID ENSDARG00000103529, External Gene Name SNX1, Location Start
# Chromosome KN150104.1: Gene ID ENSDARG00000103775, External Gene Name THBS1, Location Start
# Chromosome 5: Gene ID ENSDARG00000015879, External Gene Name PAX8, Location Start
# Chromosome 23: Gene ID ENSDARG00000019646, External Gene Name twist3, Location Start
# Chromosome 23: Gene ID ENSDARG00000098990, External Gene Name zgc:162858, Location End
# Chromosome 9: Gene ID ENSDARG00000093125, External Gene Name RANBP2, Location End
# Chromosome 9: Gene ID ENSDARG00000014976, External Gene Name lims2, Location End
# Chromosome 9: Gene ID ENSDARG00000100597, External Gene Name ubxn4, Location End
# Chromosome 17: Gene ID ENSDARG00000100019, External Gene Name arhgap11a, Location End
# Chromosome 4: Gene ID ENSDARG00000100143, External Gene Name lrp6, Location End
# Chromosome 4: Gene ID ENSDARG00000039302, External Gene Name terfa, Location Start
# Chromosome 14: Gene ID ENSDARG00000101180, External Gene Name mcm7, Location End
# Chromosome 14: Gene ID ENSDARG00000110744, External Gene Name CYTL1, Location Start
# Chromosome 14: Gene ID ENSDARG00000101794, External Gene Name atp6v0e1, Location Start
# Chromosome 14: Gene ID ENSDARG00000102317, External Gene Name rpl26, Location Start
# Chromosome 25: Gene ID ENSDARG00000102453, External Gene Name slc1a2b, Location Start
# Chromosome 13: Gene ID ENSDARG00000103415, External Gene Name ppp4r3b, Location Start
# Chromosome 13: Gene ID ENSDARG00000109902, External Gene Name tmem254, Location Start
# Chromosome 2: Gene ID ENSDARG00000100159, External Gene Name angptl1b, Location End
# Chromosome 6: Gene ID ENSDARG00000104339, External Gene Name SMARCA4, Location End
# Chromosome 11: Gene ID ENSDARG00000063527, External Gene Name elmo2, Location End
# Chromosome 11: Gene ID ENSDARG00000069977, External Gene Name myg1, Location Start
# Chromosome 11: Gene ID ENSDARG00000098574, External Gene Name srsf11, Location Start
# Chromosome 16: Gene ID ENSDARG00000098650, External Gene Name iqgap3, Location End
# Chromosome 16: Gene ID ENSDARG00000104243, External Gene Name eomesb, Location Start
# Chromosome 1: Gene ID ENSDARG00000099104, External Gene Name rpl24, Location Start
# Chromosome 1: Gene ID ENSDARG00000101364, External Gene Name wfikkn1, Location End
# Chromosome 15: Gene ID ENSDARG00000101716, External Gene Name bace1, Location End
# Chromosome 22: Gene ID ENSDARG00000112931, External Gene Name ndufaf3, Location End
# Chromosome 22: Gene ID ENSDARG00000086848, External Gene Name atad3, Location Start
# Chromosome 22: Gene ID ENSDARG00000079475, External Gene Name NCKIPSD, Location End
# Chromosome 22: Gene ID ENSDARG00000090462, External Gene Name mrpl20, Location Start
# Chromosome 21: Gene ID ENSDARG00000110357, External Gene Name txndc15, Location Start
# Chromosome 21: Gene ID ENSDARG00000023820, External Gene Name faxdc2, Location Start
# Chromosome 12: Gene ID ENSDARG00000115501, External Gene Name shisa6, Location Start
# Chromosome 24: Gene ID ENSDARG00000101627, External Gene Name ssr1, Location Start
# Chromosome 19: Gene ID ENSDARG00000078529, External Gene Name ADGRB1, Location End
# Chromosome 19: Gene ID ENSDARG00000103907, External Gene Name sgo1, Location Start
# Chromosome 18: Gene ID ENSDARG00000023659, External Gene Name gabpb1, Location End
# Chromosome 18: Gene ID ENSDARG00000063719, External Gene Name USP8, Location End
# Chromosome 18: Gene ID ENSDARG00000059349, External Gene Name homer2, Location Start
# Chromosome 8: Gene ID ENSDARG00000046022, External Gene Name tmed7, Location Start
# Chromosome 8: Gene ID ENSDARG00000111860, External Gene Name exorh, Location End
# Chromosome 8: Gene ID ENSDARG00000006990, External Gene Name CRELD1, Location Start
# Chromosome 20: Gene ID ENSDARG00000087933, External Gene Name zgc:174972, Location Start
# Chromosome 20: Gene ID ENSDARG00000078034, External Gene Name zgc:112001, Location End
# Chromosome 20: Gene ID ENSDARG00000007582, External Gene Name olfcb1, Location End
# Chromosome MT: Gene ID ENSDARG00000063895, External Gene Name mt-nd1, Location Start
# Chromosome MT: Gene ID ENSDARG00000063899, External Gene Name mt-nd2, Location Start
# Chromosome MT: Gene ID ENSDARG00000063905, External Gene Name mt-co1, Location Start
# Chromosome MT: Gene ID ENSDARG00000063908, External Gene Name mt-co2, Location Start
# Chromosome MT: Gene ID ENSDARG00000063910, External Gene Name mt-atp8, Location Start
# Chromosome MT: Gene ID ENSDARG00000063911, External Gene Name mt-atp6, Location Start
# Chromosome MT: Gene ID ENSDARG00000063912, External Gene Name mt-co3, Location Start

# %%
import csv

# Write the list of protein-coding genes near telomeric regions with external gene names and location to a CSV file
csv_file = "genes_near_telomeres.csv"

with open(csv_file, "w", newline="") as file:
    csv_writer = csv.writer(file)
    csv_writer.writerow(["Chromosome", "Gene ID", "External Gene Name", "Location"])
    for chromosome, gene_id, external_gene_name, gene_location in genes_near_telomeres:
        csv_writer.writerow([chromosome, gene_id, external_gene_name, gene_location])

print(f"Data exported to {csv_file}")
# Out:
# Data exported to genes_near_telomeres.csv

# %%
pwd
# Out:
# '/content'
